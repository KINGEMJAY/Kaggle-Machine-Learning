# %%
import pandas as pd

# Read the data from the provided tables
project_cost_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6'],
    'EstimatedCost': [100000, 150000, 200000, 250000, 300000, 350000]
})

construction_timeline_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6'],
    'EstimatedDuration': [12, 18, 24, 28, 32, 36]
})

resource_allocation_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7'],
    'ResourceCount': [50, 75, 100, 125, 150, 175, 200]
})

defect_detection_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7'],
    'DefectCount': [5, 10, 3, 6, 9, 7, 11]
})

safety_incident_prediction_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6'],
    'IncidentRate': [0.10, 0.05, 0.20, 0.09, 0.40, 0.12]
})

cost_benefit_analysis_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7'],
    'Benefit': [50000, 100000, 150000, 200000, 250000, 300000, 350000],
    'Cost': [75000, 90000, 120000, 150000, 180000, 210000, 240000]
})

labour_productivity_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6'],
    'LabourProductivity': [80, 90, 70, 100, 120, 140]
})

safety_incident_rate_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5'],
    'IncidentRate': [0.05, 0.03, 0.08, 0.02, 0.07]
})

actual_cost_prediction_df = pd.DataFrame({
    'ProjectID': [1, 2, 3, 4, 5, 6],
    'ActualCost': [500000, 750000, 1000000, 650000, 900000, 935000],
    'PredictedCost': [510000, 720000, 980000, 670000, 910000, 1000000]
})

actual_duration_prediction_df = pd.DataFrame({
    'ProjectID': [1, 2, 3, 4, 5, 6],
    'ActualDuration': [12, 18, 24, 14, 10, 17],
    'PredictedDuration': [11, 16, 25, 15, 11, 30]
})

construction_cost_optimization_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7'],
    'LabourCost': [100000, 150000, 200000, 120000, 180000, 175000, 250000],
    'MaterialCost': [50000, 80000, 100000, 60000, 90000, 120000, 150000],
    'EquipmentCost': [30000, 40000, 50000, 35000, 45000, 60000, 70000]
})

actual_predicted_defect_detection_df = pd.DataFrame({
    'ProjectID': [1, 2, 3, 4, 5, 6, 7],
    'ActualDefectCount': [5, 8, 3, 6, 4, 8, 10],
    'PredictedDefectCount': [3, 7, 4, 5, 2, 9, 11]
})

prediction_of_safety_incidences_df = pd.DataFrame({
    'ProjectID': [1, 2, 3, 4, 5, 6],
    'ActualSafetyRate': [2, 1, 0, 3, 1, 4],
    'PredictedSafetyIncident': [1, 2, 0, 4, 1, 7]
})

construction_project_data_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7'],
    'ProjectDuration': [120, 90, 150, 180, 250, 300, 350],
    'LabourCost': [500000, 400000, 600000, 800000, 1000000, 1500000, 2400000],
    'MaterialCost': [300000, 250000, 350000, 400000, 600000, 800000, 1000000],
    'AIAdoptionLevel': [10, 2, 5, 9, 1, 6, 8],
    'PercentageProductivityImprovement': [15, 8, 12, 20, 25, 28, 30]
})

ai_implementation_df = pd.DataFrame({
    'Year': [2020, 2021, 2022, 2022, 2023, 2023],
    'Hours': [200, 300, 150, 250, 180, 140],
    'CostSaving': [100000, 150000, 80000, 120000, 90000, 180000],
    'OptimumProductivity': [10, 12, 8, 15, 9, 10]
})

efficiency_cost_time_savings_df = pd.DataFrame({
    'ProjectID': ['P1', 'P2', 'P3', 'P4', 'P5'],
    'CostNaira': [10000, 30000, 20000, 15000, 12000],
    'TimeSavings':[10, 14, 15, 13, 12],
    'ErrorPercentage':[0.50, 0.45, 0.35, 0.30, 0.40],
    'EfficiencyPercentage': [15, 18, 17, 20, 15]
})


# Perform further analysis as per your thesis requirements

# Example: Calculate the average estimated cost and duration
average_cost = project_cost_df['EstimatedCost'].mean()
average_duration = construction_timeline_df['EstimatedDuration'].mean()

# Print the results
print("Estimated Cost:", average_cost)
print("Estimated Duration:", average_duration)
# Out:
# Estimated Cost: 225000.0
# Estimated Duration: 25.0
